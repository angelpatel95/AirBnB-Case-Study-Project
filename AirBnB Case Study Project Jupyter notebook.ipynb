# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidance to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this intire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to similate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('../files/AB_NYC_2019.csv')
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# How many neighborhood groups are available and which shows up the most?
air_neighbourhood=air_bnb.groupby('neighbourhood_group', as_index=False).count()[['id','neighbourhood_group','price']]
air_neighbourhood.head()

# 5 groups and Manhattan appears the most
# Out:
#       id neighbourhood_group  price
# 0   1091               Bronx   1091
# 1  20104            Brooklyn  20104
# 2  21661           Manhattan  21661
# 3   5666              Queens   5666
# 4    373       Staten Island    373

# %%
# Are private rooms the most popular in manhattan?
air_man_private = air_bnb.groupby(['neighbourhood_group', 'room_type']).count()
air_man_private

# no, entire home/apt is the most popular
# Out:
#                                         id   name  host_id  host_name  \
# neighbourhood_group room_type
# Bronx               Entire home/apt    379    379      379        378
#                     Private room       652    652      652        652
#                     Shared room         60     59       60         60
# Brooklyn            Entire home/apt   9559   9558     9559       9554
#                     Private room     10132  10127    10132      10128
#                     Shared room        413    413      413        413
# Manhattan           Entire home/apt  13199  13193    13199      13196
#                     Private room      7982   7979     7982       7976
#                     Shared room        480    480      480        480
# Queens              Entire home/apt   2096   2096     2096       2096
#                     Private room      3372   3372     3372       3370
#                     Shared room        198    198      198        198
# ...

# %%
# Which hosts are the busiest and based on their reviews?
hosts = air_bnb.groupby('host_id').sum()[['id','number_of_reviews']]
hosts.sort_values(by=['number_of_reviews'],ascending=False).head()

#
# Out:
#                  id  number_of_reviews
# host_id
# 37312959   51232186               2273
# 344035    155403744               2205
# 26432133   74542317               2017
# 35524316   76057984               1971
# 40176101   70447963               1818

# %%
#Which neighorhood group has the highest average price?
price = air_bnb.groupby('neighbourhood_group').mean().round(decimals=2)[['id','price']]
price.sort_values(by=['price'],ascending=False).head()

# Manhattan
# Out:
#                               id   price
# neighbourhood_group
# Manhattan            18774939.21  196.88
# Brooklyn             18256853.98  124.38
# Staten Island        21597473.06  114.81
# Queens               21754997.22   99.52
# Bronx                22734918.60   87.50

# %%
# Which neighbor hood group has the highest total price?
price = air_bnb.groupby('neighbourhood_group').sum()[['id','price']]
price.sort_values(by=['price'],ascending=False).head()

# Manhattan
# Out:
#                                id    price
# neighbourhood_group
# Manhattan            406683958152  4264527
# Brooklyn             367035792483  2500600
# Queens               123263814259   563867
# Bronx                 24803796188    95459
# Staten Island          8055857451    42825

# %%
#Which top 5 hosts have the highest total price?
price = air_bnb.groupby('host_name').sum()[['id','price']]
price.sort_values(by=['price'],ascending=False).head()

# Sonder, Blueground, Micheal, David, Alex
# Out:
#                        id  price
# host_name
# Sonder (NYC)  10885561678  82795
# Blueground     7210036953  70331
# Michael        7430617239  66895
# David          7943862898  65844
# Alex           5496620312  52563

# %%
# Who currently has no (zero) availability with a review count of 100 or more?
zero_avail = air_bnb[air_bnb['availability_365'] == 0]
zero_reviewed = zero_avail[zero_avail['number_of_reviews'] >= 100]
zero_reviewed
# Out:
#              id                                       name    host_id  \
# 8          5203         Cozy Clean Guest Room - Family Apt       7490
# 94        20913         Charming 1 bed GR8 WBurg LOCATION!      79402
# 132       30031           NYC artists’ loft with roof deck     129352
# 174       44221             Financial District Luxury Loft     193722
# 180       45556      Fort Greene, Brooklyn: Center Bedroom      67778
# ...         ...                                        ...        ...
# 29581  22705516         The Quietest Block in Manhattan :)  127740507
# 30461  23574142                          queens get away!!  176185168
# 31250  24267706  entire sunshine of the spotless mind room   21074914
# 32670  25719044                COZY Room for Female Guests   40119874
# 35014  27759146     Cozy corner near Empire State Building  209549523
#
#         host_name neighbourhood_group              neighbourhood  latitude  \
# ...

# %%
# What host has the highest total of prices and where are they located?
host_price = air_bnb.groupby('host_id').sum()[['id','price',]]
host_price.sort_values(by=['price'],ascending=False).head()

host_id_loc = air_bnb[air_bnb['host_id']==219517861]
host_id_loc
# Out:
#              id                                               name    host_id  \
# 38293  30181691      Sonder | 180 Water | Incredible 2BR + Rooftop  219517861
# 38294  30181945         Sonder | 180 Water | Premier 1BR + Rooftop  219517861
# 38588  30347708        Sonder | 180 Water | Charming 1BR + Rooftop  219517861
# 39769  30937590            Sonder | The Nash | Artsy 1BR + Rooftop  219517861
# 39770  30937591        Sonder | The Nash | Lovely Studio + Rooftop  219517861
# ...         ...                                                ...        ...
# 47691  35871510  Sonder | 116 John | Vibrant Studio + Fitness Room  219517861
# 47692  35871511     Sonder | 116 John | Vibrant 1BR + Fitness Room  219517861
# 47693  35871515         Sonder | 116 John | Stunning 1BR + Rooftop  219517861
# 47814  35936418          Sonder | 116 John | Polished Studio + Gym  219517861
# 47821  35937891            Sonder | 116 John | Simple Studio + Gym  219517861
#
# ...

# %%
# When did Danielle from Queens last receive a review?
danielle = air_bnb[air_bnb['host_name']=='Danielle']
danielle_queens = danielle[danielle['neighbourhood_group']=='Queens']
danielle_queens[['host_name','host_id','last_review']]
# Out:
#       host_name    host_id last_review
# 7086   Danielle   26432133  2019-07-03
# 16349  Danielle   18051286         NaN
# 20403  Danielle   26432133  2019-07-06
# 21517  Danielle   26432133  2019-07-07
# 22068  Danielle   26432133  2019-07-06
# 22469  Danielle   26432133  2019-07-08
# 27021  Danielle  154256662  2018-01-02
# 33861  Danielle  201647469  2019-06-20

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %%
host_count = air_bnb.groupby('host_id').count()[['id','price']]
host_count.sort_values(by=['id'],ascending=False).head()
# Out:
#             id  price
# host_id
# 219517861  327    327
# 107434423  232    232
# 30283594   121    121
# 137358866  103    103
# 16098958    96     96

# %% [markdown]
# 2. How many listings have completely open availability?

# %%
full_avail = air_bnb[air_bnb['availability_365']==365]
full_avail
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 36        11452                        Clean and Quiet in Brooklyn       7355
# 38        11943                          Country space in the city      45445
# 97        21644                          Upper Manhattan, New York      82685
# ...         ...                                                ...        ...
# 48744  36415840         A BEAUTIFUL SPACE IN HEART OF WILLIAMSBURG  223715460
# 48844  36453952    West Village Studio on quiet cobblestone street  115491896
# 48868  36473253                       Heaven for you(only for guy)  261338177
# 48880  36481315  The Raccoon Artist Studio in Williamsburg New ...  208514239
# 48887  36483152    Garden Jewel Apartment in Williamsburg New York  208514239
#
# ...

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %%
room_types = air_bnb.groupby('room_type').count()[['price','number_of_reviews']]
room_types
# Out:
#                  price  number_of_reviews
# room_type
# Entire home/apt  25409              25409
# Private room     22326              22326
# Shared room       1160               1160

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --
